# %% [markdown]
# # Pandas

# %% [markdown]
# Το [pandas](http://pandas.pydata.org/) είναι μία βιβλιοθήκη σε python για ανάλυση δεδομένων. Υιοθετεί τη φιλοσοφία της Matlab και R για οργάνωση 2-διάστατων δεδομένων σε μία ειδική δομή που ονομάζεται data frame. Στη βιοπληροφορική το pandas συνήθως είναι χρήσιμο για να κάνουμε εργασίες που συνήθως γίνονται με το excel. Τα πλεονεκτήματα του pandas είναι:
#
# * Πάρα πολύ γρήγορο. Είναι υλοποιημένο σε C (η python "τρέχει" από πάνω) και έχει πολύ καλή απόδοση για πίνακες που έχουν μέχρι και εκατομύρια από γραμμές.
# * Παρέχει ένα interface το οποίο προσομοιάζει τις βάσεις δεδομένων. Με αυτόν τον τρόπο μπορούμε να γράφουμε σύντομες εκφράσεις που κάνουν πολύπλοκες διεργασίες.
#    * Αναλύοντας σε όρους Computer Science το παραπάνω λέμε ότι η pandas προσφέρει μία "[δηλωτική γλώσσα](https://en.wikipedia.org/wiki/Declarative_programming)", σε αντίθεση με τη κλασσική python που δηλώνεις τη [ροή εκτέλεσης](https://en.wikipedia.org/wiki/Control_flow) μίας διεργασίας.
# * Υποστηρίζεται από τρίτες βιβλιοθήκες για visualization, Machine Learning (π.χ. [sci-kit](http://scikit-learn.org/stable/)) και στατιστική (π.χ. [statmodels](http://statsmodels.sourceforge.net/)).
# * Παρέχει δικές του μεθόδους για γρήγορο plotting και στατιστική ανάλυση
# * Εύκολη και γρήγορο input / output σε διάφορα formats (excel included)

# %% [markdown]
# Συνήθως κάνουμε import το pandas ως εξής:

# %%
import pandas as pd

# %% [markdown]
# Αν δεν υπάρχει εγκαταστημένων τότε μπορείτε να το εγκαταστείσετε ως εξής:
#
# ```bash
# pip install pandas
# ```
#
# Προσοχή. Πρέπει το ```pip``` να βρίσκεται στην ίδια τοποθεσία που βρίσκεται και η python

# %%
hs = pd.read_csv('https://ftp.ncbi.nlm.nih.gov/gene/DATA/GENE_INFO/Mammalia/Homo_sapiens.gene_info.gz', sep='\t')

# %% [markdown]
# Το ```sep='\t'``` σημαίνει ότι οι στήλες χωρίζονται από tabs.

# %% [markdown]
# Οι πρώτες γραμμές:

# %%
hs.head()
# Out:
#    #tax_id  GeneID Symbol LocusTag                   Synonyms  \
# 0     9606       1   A1BG        -       A1B|ABG|GAB|HYST2477
# 1     9606       2    A2M        -  A2MD|CPAMD5|FWP007|S863-7
# 2     9606       3  A2MP1        -                       A2MP
# 3     9606       9   NAT1        -       AAC1|MNAT|NAT-1|NATI
# 4     9606      10   NAT2        -            AAC2|NAT-2|PNAT
#
#                                              dbXrefs chromosome map_location  \
# 0     MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410         19     19q13.43
# 1     MIM:103950|HGNC:HGNC:7|Ensembl:ENSG00000175899         12     12p13.31
# 2                HGNC:HGNC:8|Ensembl:ENSG00000256069         12     12p13.31
# 3  MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171428          8         8p22
# 4  MIM:612182|HGNC:HGNC:7646|Ensembl:ENSG00000156006          8         8p22
#
#                           description    type_of_gene  \
# 0              alpha-1-B glycoprotein  protein-coding
# 1               alpha-2-macroglobulin  protein-coding
# 2  alpha-2-macroglobulin pseudogene 1          pseudo
# 3               N-acetyltransferase 1  protein-coding
# 4               N-acetyltransferase 2  protein-coding
#
#   Symbol_from_nomenclature_authority Full_name_from_nomenclature_authority  \
# 0                               A1BG                alpha-1-B glycoprotein
# 1                                A2M                 alpha-2-macroglobulin
# 2                              A2MP1    alpha-2-macroglobulin pseudogene 1
# 3                               NAT1                 N-acetyltransferase 1
# 4                               NAT2                 N-acetyltransferase 2
#
#   Nomenclature_status                                 Other_designations  \
# 0                   O  alpha-1B-glycoprotein|HEL-S-163pA|epididymis s...
# 1                   O  alpha-2-macroglobulin|C3 and PZP-like alpha-2-...
# 2                   O                  pregnancy-zone protein pseudogene
# 3                   O  arylamine N-acetyltransferase 1|N-acetyltransf...
# 4                   O  arylamine N-acetyltransferase 2|N-acetyltransf...
#
#    Modification_date Feature_type
# 0           20210302            -
# 1           20210404            -
# 2           20210302            -
# 3           20210302            -
# 4           20210322            -

# %% [markdown]
# Οι τελευταίες:

# %%
hs.tail()
# Out:
#        #tax_id   GeneID    Symbol LocusTag Synonyms dbXrefs chromosome  \
# 62011   741158  8923215      trnD        -        -       -         MT
# 62012   741158  8923216      trnP        -        -       -         MT
# 62013   741158  8923217      trnA        -        -       -         MT
# 62014   741158  8923218      COX1        -        -       -         MT
# 62015   741158  8923219  16S rRNA        -        -       -         MT
#
#       map_location                     description    type_of_gene  \
# 62011            -                            tRNA            tRNA
# 62012            -                            tRNA            tRNA
# 62013            -                            tRNA            tRNA
# 62014            -  cytochrome c oxidase subunit I  protein-coding
# 62015            -                          l-rRNA            rRNA
#
#       Symbol_from_nomenclature_authority  \
# 62011                                  -
# 62012                                  -
# 62013                                  -
# 62014                                  -
# 62015                                  -
#
#       Full_name_from_nomenclature_authority Nomenclature_status  \
# 62011                                     -                   -
# 62012                                     -                   -
# 62013                                     -                   -
# 62014                                     -                   -
# 62015                                     -                   -
#
#                    Other_designations  Modification_date Feature_type
# 62011                               -           20200909            -
# 62012                               -           20200909            -
# 62013                               -           20200909            -
# 62014  cytochrome c oxidase subunit I           20200909            -
# 62015                               -           20200909            -

# %% [markdown]
# Το ίδιο μπορούμε να κάνουμε με:

# %%
hs[:5] # Πρώτες 5 γραμμές
# Out:
#    #tax_id  GeneID Symbol LocusTag                   Synonyms  \
# 0     9606       1   A1BG        -       A1B|ABG|GAB|HYST2477
# 1     9606       2    A2M        -  A2MD|CPAMD5|FWP007|S863-7
# 2     9606       3  A2MP1        -                       A2MP
# 3     9606       9   NAT1        -       AAC1|MNAT|NAT-1|NATI
# 4     9606      10   NAT2        -            AAC2|NAT-2|PNAT
#
#                                              dbXrefs chromosome map_location  \
# 0     MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410         19     19q13.43
# 1     MIM:103950|HGNC:HGNC:7|Ensembl:ENSG00000175899         12     12p13.31
# 2                HGNC:HGNC:8|Ensembl:ENSG00000256069         12     12p13.31
# 3  MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171428          8         8p22
# 4  MIM:612182|HGNC:HGNC:7646|Ensembl:ENSG00000156006          8         8p22
#
#                           description    type_of_gene  \
# 0              alpha-1-B glycoprotein  protein-coding
# 1               alpha-2-macroglobulin  protein-coding
# 2  alpha-2-macroglobulin pseudogene 1          pseudo
# 3               N-acetyltransferase 1  protein-coding
# 4               N-acetyltransferase 2  protein-coding
#
#   Symbol_from_nomenclature_authority Full_name_from_nomenclature_authority  \
# 0                               A1BG                alpha-1-B glycoprotein
# 1                                A2M                 alpha-2-macroglobulin
# 2                              A2MP1    alpha-2-macroglobulin pseudogene 1
# 3                               NAT1                 N-acetyltransferase 1
# 4                               NAT2                 N-acetyltransferase 2
#
#   Nomenclature_status                                 Other_designations  \
# 0                   O  alpha-1B-glycoprotein|HEL-S-163pA|epididymis s...
# 1                   O  alpha-2-macroglobulin|C3 and PZP-like alpha-2-...
# 2                   O                  pregnancy-zone protein pseudogene
# 3                   O  arylamine N-acetyltransferase 1|N-acetyltransf...
# 4                   O  arylamine N-acetyltransferase 2|N-acetyltransf...
#
#    Modification_date Feature_type
# 0           20210302            -
# 1           20210404            -
# 2           20210302            -
# 3           20210302            -
# 4           20210322            -

# %%
hs[-5:]
# Out:
#        #tax_id   GeneID    Symbol LocusTag Synonyms dbXrefs chromosome  \
# 62011   741158  8923215      trnD        -        -       -         MT
# 62012   741158  8923216      trnP        -        -       -         MT
# 62013   741158  8923217      trnA        -        -       -         MT
# 62014   741158  8923218      COX1        -        -       -         MT
# 62015   741158  8923219  16S rRNA        -        -       -         MT
#
#       map_location                     description    type_of_gene  \
# 62011            -                            tRNA            tRNA
# 62012            -                            tRNA            tRNA
# 62013            -                            tRNA            tRNA
# 62014            -  cytochrome c oxidase subunit I  protein-coding
# 62015            -                          l-rRNA            rRNA
#
#       Symbol_from_nomenclature_authority  \
# 62011                                  -
# 62012                                  -
# 62013                                  -
# 62014                                  -
# 62015                                  -
#
#       Full_name_from_nomenclature_authority Nomenclature_status  \
# 62011                                     -                   -
# 62012                                     -                   -
# 62013                                     -                   -
# 62014                                     -                   -
# 62015                                     -                   -
#
#                    Other_designations  Modification_date Feature_type
# 62011                               -           20200909            -
# 62012                               -           20200909            -
# 62013                               -           20200909            -
# 62014  cytochrome c oxidase subunit I           20200909            -
# 62015                               -           20200909            -

# %% [markdown]
# Ας δούμε όλες τις στήλες:

# %%
hs.columns
# Out:
# Index(['#tax_id', 'GeneID', 'Symbol', 'LocusTag', 'Synonyms', 'dbXrefs',
#        'chromosome', 'map_location', 'description', 'type_of_gene',
#        'Symbol_from_nomenclature_authority',
#        'Full_name_from_nomenclature_authority', 'Nomenclature_status',
#        'Other_designations', 'Modification_date', 'Feature_type'],
#       dtype='object')

# %% [markdown]
# Ή σε λίστα:

# %%
list(hs.columns.values)
# Out:
# ['#tax_id',
#  'GeneID',
#  'Symbol',
#  'LocusTag',
#  'Synonyms',
#  'dbXrefs',
#  'chromosome',
#  'map_location',
#  'description',
#  'type_of_gene',
#  'Symbol_from_nomenclature_authority',
#  'Full_name_from_nomenclature_authority',
#  'Nomenclature_status',
#  'Other_designations',
#  'Modification_date',
#  'Feature_type']

# %% [markdown]
# Ωραία. Ας πάρουμε μόνο τρείς στήλες:

# %%
hs[['Symbol', 'chromosome', 'type_of_gene']][:5]
# Out:
#   Symbol chromosome    type_of_gene
# 0   A1BG         19  protein-coding
# 1    A2M         12  protein-coding
# 2  A2MP1         12          pseudo
# 3   NAT1          8  protein-coding
# 4   NAT2          8  protein-coding

# %% [markdown]
# Προσοχή! Το παραπάνω είναι ισοδύναμο με:

# %%
hs[:5][['Symbol', 'chromosome', 'type_of_gene']]
# Out:
#   Symbol chromosome    type_of_gene
# 0   A1BG         19  protein-coding
# 1    A2M         12  protein-coding
# 2  A2MP1         12          pseudo
# 3   NAT1          8  protein-coding
# 4   NAT2          8  protein-coding

# %% [markdown]
# Πόσες γραμμές και πόσες στήλες έχει το Data Frame;

# %%
hs.shape
# Out:
# (62016, 16)

# %% [markdown]
# ### Indexes

# %% [markdown]
# Ένα dataframe πρέπει να έχει ένα index. Ή αλλιώς μία στήλη που έχει μοναδική τιμή για όλες τις γραμμές. Από default η στήλη αυτή είναι ο αύξων αριθμός της γραμμής. Μπορείτε με αυτό τον τρόπο να πάρετε οποιαδήποτε γραμμή με βάση το index της με την iloc:

# %%
hs.iloc[10]
# Out:
# #tax_id                                                                               9606
# GeneID                                                                                  16
# Symbol                                                                               AARS1
# LocusTag                                                                                 -
# Synonyms                                                           AARS|CMT2N|DEE29|EIEE29
# dbXrefs                                    MIM:601065|HGNC:HGNC:20|Ensembl:ENSG00000090861
# chromosome                                                                              16
# map_location                                                                       16q22.1
# description                                                       alanyl-tRNA synthetase 1
# type_of_gene                                                                protein-coding
# Symbol_from_nomenclature_authority                                                   AARS1
# Full_name_from_nomenclature_authority                             alanyl-tRNA synthetase 1
# Nomenclature_status                                                                      O
# Other_designations                       alanine--tRNA ligase, cytoplasmic|alaRS|alanin...
# Modification_date                                                                 20210404
# Feature_type                                                                             -
# New_date                                                               2021-04-04 00:00:00
# Name: 10, dtype: object

# %%
hs.iloc[:2]
# Out:
#    #tax_id  GeneID Symbol LocusTag                   Synonyms  \
# 0     9606       1   A1BG        -       A1B|ABG|GAB|HYST2477
# 1     9606       2    A2M        -  A2MD|CPAMD5|FWP007|S863-7
#
#                                           dbXrefs chromosome map_location  \
# 0  MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410         19     19q13.43
# 1  MIM:103950|HGNC:HGNC:7|Ensembl:ENSG00000175899         12     12p13.31
#
#               description    type_of_gene Symbol_from_nomenclature_authority  \
# 0  alpha-1-B glycoprotein  protein-coding                               A1BG
# 1   alpha-2-macroglobulin  protein-coding                                A2M
#
#   Full_name_from_nomenclature_authority Nomenclature_status  \
# 0                alpha-1-B glycoprotein                   O
# 1                 alpha-2-macroglobulin                   O
#
#                                   Other_designations  Modification_date  \
# 0  alpha-1B-glycoprotein|HEL-S-163pA|epididymis s...           20210302
# 1  alpha-2-macroglobulin|C3 and PZP-like alpha-2-...           20210404
#
#   Feature_type  is_pseudo
# 0            -      False
# 1            -      False

# %% [markdown]
# Οι γραμμές 100, 200 και 400:

# %%
hs.iloc[[100, 200, 400]]
# Out:
#      #tax_id  GeneID  Symbol LocusTag               Synonyms  \
# 100     9606     119    ADD2        -                   ADDB
# 200     9606     240   ALOX5        -   5-LO|5-LOX|5LPG|LOG5
# 400     9606     479  ATP12A        -  ATP1AL1|H-K-ATPase|HK
#
#                                                dbXrefs chromosome  \
# 100   MIM:102681|HGNC:HGNC:244|Ensembl:ENSG00000075340          2
# 200   MIM:152390|HGNC:HGNC:435|Ensembl:ENSG00000012779         10
# 400  MIM:182360|HGNC:HGNC:13816|Ensembl:ENSG0000007...         13
#
#                map_location  \
# 100                  2p13.3
# 200                10q11.21
# 400  13q12.12|13q12.1-q12.3
#
#                                            description    type_of_gene  \
# 100                                          adducin 2  protein-coding
# 200                        arachidonate 5-lipoxygenase  protein-coding
# 400  ATPase H+/K+ transporting non-gastric alpha2 s...  protein-coding
#
#     Symbol_from_nomenclature_authority  \
# 100                               ADD2
# 200                              ALOX5
# 400                             ATP12A
#
#                  Full_name_from_nomenclature_authority Nomenclature_status  \
# 100                                          adducin 2                   O
# 200                        arachidonate 5-lipoxygenase                   O
# 400  ATPase H+/K+ transporting non-gastric alpha2 s...                   O
#
#                                     Other_designations  Modification_date  \
# 100  beta-adducin|adducin 2 (beta)|erythrocyte addu...           20210302
# 200  polyunsaturated fatty acid 5-lipoxygenase|LOX-...           20210406
# 400  potassium-transporting ATPase alpha chain 2|AT...           20210302
#
#     Feature_type  is_pseudo
# 100            -      False
# 200            -      False
# 400            -      False

# %% [markdown]
# ## Filtering

# %% [markdown]
# Με το όρο filtering εννοούμε το να εισάγουμε φίλτρα στα δεδομένα μας ώστε να εμφανιστούν μόνο αυτά που έχουν (ή δεν έχουν..) μια ιδιότητα. Ένας ανάλογος όρος είναι το query (ή querying), ή αλλιώς "επερώτηση", όπου "ρωτάμε" ποια δεδομένα έχουν μία ιδιότητα.
#
# Η pandas και η numpy (θα τα δούμε σε επόμενη διάλεξη) έχουν έναν κοινό μηχανισμό για να κάνουν filter. Το ενδιαφέρον είναι ότι ο μηχανισμός αυτός είναι, [επηρεασμένος](https://github.com/pandas-dev/pandas) από την R. Ας τον δούμε λίγο. Για αρχή πρέπει να φτιάξουμε μία λίστα η οποία να έχει το ίδιο μέγεθος με τις γραμμές του DataFrame. Η λίστα αυτή θα έχει μόνο τιμές True ή False. Στη συνέχεια δηλώνουμε αυτή τη λίστα σαν δείκτης σε μία λίστα. Ας το δούμε στη πράξη αυτό:
#
# Ας υποθέσουμε ότι θέλουμε μόνο τις μονές γραμμές του dataframe. Φτιάχνουμε μία λίστα όπου οι μονές θέσεις περιέχουν τη τιμή True και οι άρτιες τη τιμή False:

# %%
rows = hs.shape[0]
l = [x%2==1 for x in range(rows)]

# %% [markdown]
# Τώρα το l μπορεί να λειτουργήσει σαν φίλτρο άν το περάσουμε σε ένα Data Frame:

# %%
hs_filtered = hs[l]

# %%
hs_filtered.shape # Οι μισές γραμμες
# Out:
# (31008, 16)

# %%
hs_filtered.head()
# Out:
#    #tax_id  GeneID Symbol LocusTag                   Synonyms  \
# 1     9606       2    A2M        -  A2MD|CPAMD5|FWP007|S863-7
# 3     9606       9   NAT1        -       AAC1|MNAT|NAT-1|NATI
# 5     9606      11   NATP        -                 AACP|NATP1
# 7     9606      13  AADAC        -                 CES5A1|DAC
# 9     9606      15  AANAT        -                  DSPS|SNAT
#
#                                              dbXrefs chromosome map_location  \
# 1     MIM:103950|HGNC:HGNC:7|Ensembl:ENSG00000175899         12     12p13.31
# 3  MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171428          8         8p22
# 5                                       HGNC:HGNC:15          8         8p22
# 7    MIM:600338|HGNC:HGNC:17|Ensembl:ENSG00000114771          3       3q25.1
# 9    MIM:600950|HGNC:HGNC:19|Ensembl:ENSG00000129673         17      17q25.1
#
#                         description    type_of_gene  \
# 1             alpha-2-macroglobulin  protein-coding
# 3             N-acetyltransferase 1  protein-coding
# 5    N-acetyltransferase pseudogene          pseudo
# 7         arylacetamide deacetylase  protein-coding
# 9  aralkylamine N-acetyltransferase  protein-coding
#
#   Symbol_from_nomenclature_authority Full_name_from_nomenclature_authority  \
# 1                                A2M                 alpha-2-macroglobulin
# 3                               NAT1                 N-acetyltransferase 1
# 5                               NATP        N-acetyltransferase pseudogene
# 7                              AADAC             arylacetamide deacetylase
# 9                              AANAT      aralkylamine N-acetyltransferase
#
#   Nomenclature_status                                 Other_designations  \
# 1                   O  alpha-2-macroglobulin|C3 and PZP-like alpha-2-...
# 3                   O  arylamine N-acetyltransferase 1|N-acetyltransf...
# 5                   O                     arylamide acetylase pseudogene
# 7                   O  arylacetamide deacetylase|arylacetamide deacet...
# 9                   O  serotonin N-acetyltransferase|arylalkylamine N...
#
#    Modification_date Feature_type
# 1           20210404            -
# 3           20210302            -
# 5           20210302            -
# 7           20210302            -
# 9           20210302            -

# %% [markdown]
# Παρατηρούμε ότι έχει τους μονούς δείκτες.
#
# ΟΚ, αλλά πως γίνεται αυτό να με βοηθήσει να κάνω filtering; Μπορούμε πολύ απλά να κάνουμε μία λογική πράξη με μία στήλη και το αποτέλεσμα είναι μία λίστα με λογικές τιμες η οποία μπορεί να χρησιμοποιειθεί σαν φίλτρο! Για παράδειγμα. Όλα τα γονίδια που ανήκουν στο χρωμόσωμα 8:

# %%
filter_chr_8 = hs['chromosome'] == '8'

# %%
filter_chr_8[:10] # Τυπώνουμε τα πρώτα 10d
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: chromosome, dtype: bool

# %% [markdown]
# Επιβεβαιώνουμε με:

# %%
hs['chromosome'][:10]
# Out:
# 0    19
# 1    12
# 2    12
# 3     8
# 4     8
# 5     8
# 6    14
# 7     3
# 8     2
# 9    17
# Name: chromosome, dtype: object

# %% [markdown]
# τώρα μπορούμε να εφαρμόσουμε αυτό το φίλτρο:

# %%
hs[filter_chr_8][:10] # Τα πρώτα 10 γονίδια στο χρωμόσωμα 8
# Out:
#      #tax_id  GeneID  Symbol LocusTag                  Synonyms  \
# 3       9606       9    NAT1        -      AAC1|MNAT|NAT-1|NATI
# 4       9606      10    NAT2        -           AAC2|NAT-2|PNAT
# 5       9606      11    NATP        -                AACP|NATP1
# 54      9606      66  ACTBP6        -           H8-PSI-BETA-AC3
# 95      9606     114   ADCY8        -           AC8|ADCY3|HBAC1
# 125     9606     148  ADRA1A        -  ADRA1C|ADRA1L1|ALPHA1AAR
# 131     9606     155   ADRB3        -                   BETA3AR
# 237     9606     284  ANGPT1        -            AGP1|AGPT|ANG1
# 238     9606     285  ANGPT2        -                AGPT2|ANG2
# 239     9606     286    ANK1        -             ANK|SPH1|SPH2
#
#                                                dbXrefs chromosome  \
# 3    MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171428          8
# 4    MIM:612182|HGNC:HGNC:7646|Ensembl:ENSG00000156006          8
# 5                                         HGNC:HGNC:15          8
# 54                                       HGNC:HGNC:139          8
# 95    MIM:103070|HGNC:HGNC:239|Ensembl:ENSG00000155897          8
# 125   MIM:104221|HGNC:HGNC:277|Ensembl:ENSG00000120907          8
# 131   MIM:109691|HGNC:HGNC:288|Ensembl:ENSG00000188778          8
# 237   MIM:601667|HGNC:HGNC:484|Ensembl:ENSG00000154188          8
# 238   MIM:601922|HGNC:HGNC:485|Ensembl:ENSG00000091879          8
# 239   MIM:612641|HGNC:HGNC:492|Ensembl:ENSG00000029534          8
#
#     map_location                     description    type_of_gene  \
# 3           8p22           N-acetyltransferase 1  protein-coding
# 4           8p22           N-acetyltransferase 2  protein-coding
# 5           8p22  N-acetyltransferase pseudogene          pseudo
# 54        8q21.2               ACTB pseudogene 6          pseudo
# 95       8q24.22             adenylate cyclase 8  protein-coding
# 125       8p21.2           adrenoceptor alpha 1A  protein-coding
# 131      8p11.23             adrenoceptor beta 3  protein-coding
# 237       8q23.1                  angiopoietin 1  protein-coding
# 238       8p23.1                  angiopoietin 2  protein-coding
# 239      8p11.21                       ankyrin 1  protein-coding
#
#     Symbol_from_nomenclature_authority Full_name_from_nomenclature_authority  \
# 3                                 NAT1                 N-acetyltransferase 1
# 4                                 NAT2                 N-acetyltransferase 2
# 5                                 NATP        N-acetyltransferase pseudogene
# 54                              ACTBP6                     ACTB pseudogene 6
# 95                               ADCY8                   adenylate cyclase 8
# 125                             ADRA1A                 adrenoceptor alpha 1A
# 131                              ADRB3                   adrenoceptor beta 3
# 237                             ANGPT1                        angiopoietin 1
# 238                             ANGPT2                        angiopoietin 2
# 239                               ANK1                             ankyrin 1
#
#     Nomenclature_status                                 Other_designations  \
# 3                     O  arylamine N-acetyltransferase 1|N-acetyltransf...
# 4                     O  arylamine N-acetyltransferase 2|N-acetyltransf...
# 5                     O                     arylamide acetylase pseudogene
# 54                    O  actin, beta pseudogene 6|actin, gamma 1 pseudo...
# 95                    O  adenylate cyclase type 8|ATP pyrophosphate-lya...
# 125                   O  alpha-1A adrenergic receptor|G protein coupled...
# 131                   O  beta-3 adrenergic receptor|adrenergic, beta-3-...
# 237                   O                               angiopoietin-1|ANG-1
# 238                   O  angiopoietin-2|Tie2-ligand|angiopoietin-2B|ang...
# 239                   O  ankyrin-1|ANK-1|ankyrin 1, erythrocytic|ankyri...
#
#      Modification_date Feature_type
# 3             20210302            -
# 4             20210322            -
# 5             20210302            -
# 54            20210302            -
# 95            20210302            -
# 125           20210302            -
# 131           20210322            -
# 237           20210406            -
# 238           20210406            -
# 239           20210302            -

# %% [markdown]
# Αν αντικαταστήσουμε το ```filter_chr_8``` με το ```hs['chromosome'] == '8'``` (δες και κελί 35) θα έχουμε:

# %%
hs[hs['chromosome'] == '8'][:10]
# Out:
#      #tax_id  GeneID  Symbol LocusTag                  Synonyms  \
# 3       9606       9    NAT1        -      AAC1|MNAT|NAT-1|NATI
# 4       9606      10    NAT2        -           AAC2|NAT-2|PNAT
# 5       9606      11    NATP        -                AACP|NATP1
# 54      9606      66  ACTBP6        -           H8-PSI-BETA-AC3
# 95      9606     114   ADCY8        -           AC8|ADCY3|HBAC1
# 125     9606     148  ADRA1A        -  ADRA1C|ADRA1L1|ALPHA1AAR
# 131     9606     155   ADRB3        -                   BETA3AR
# 237     9606     284  ANGPT1        -            AGP1|AGPT|ANG1
# 238     9606     285  ANGPT2        -                AGPT2|ANG2
# 239     9606     286    ANK1        -             ANK|SPH1|SPH2
#
#                                                dbXrefs chromosome  \
# 3    MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171428          8
# 4    MIM:612182|HGNC:HGNC:7646|Ensembl:ENSG00000156006          8
# 5                                         HGNC:HGNC:15          8
# 54                                       HGNC:HGNC:139          8
# 95    MIM:103070|HGNC:HGNC:239|Ensembl:ENSG00000155897          8
# 125   MIM:104221|HGNC:HGNC:277|Ensembl:ENSG00000120907          8
# 131   MIM:109691|HGNC:HGNC:288|Ensembl:ENSG00000188778          8
# 237   MIM:601667|HGNC:HGNC:484|Ensembl:ENSG00000154188          8
# 238   MIM:601922|HGNC:HGNC:485|Ensembl:ENSG00000091879          8
# 239   MIM:612641|HGNC:HGNC:492|Ensembl:ENSG00000029534          8
#
#     map_location                     description    type_of_gene  \
# 3           8p22           N-acetyltransferase 1  protein-coding
# 4           8p22           N-acetyltransferase 2  protein-coding
# 5           8p22  N-acetyltransferase pseudogene          pseudo
# 54        8q21.2               ACTB pseudogene 6          pseudo
# 95       8q24.22             adenylate cyclase 8  protein-coding
# 125       8p21.2           adrenoceptor alpha 1A  protein-coding
# 131      8p11.23             adrenoceptor beta 3  protein-coding
# 237       8q23.1                  angiopoietin 1  protein-coding
# 238       8p23.1                  angiopoietin 2  protein-coding
# 239      8p11.21                       ankyrin 1  protein-coding
#
#     Symbol_from_nomenclature_authority Full_name_from_nomenclature_authority  \
# 3                                 NAT1                 N-acetyltransferase 1
# 4                                 NAT2                 N-acetyltransferase 2
# 5                                 NATP        N-acetyltransferase pseudogene
# 54                              ACTBP6                     ACTB pseudogene 6
# 95                               ADCY8                   adenylate cyclase 8
# 125                             ADRA1A                 adrenoceptor alpha 1A
# 131                              ADRB3                   adrenoceptor beta 3
# 237                             ANGPT1                        angiopoietin 1
# 238                             ANGPT2                        angiopoietin 2
# 239                               ANK1                             ankyrin 1
#
#     Nomenclature_status                                 Other_designations  \
# 3                     O  arylamine N-acetyltransferase 1|N-acetyltransf...
# 4                     O  arylamine N-acetyltransferase 2|N-acetyltransf...
# 5                     O                     arylamide acetylase pseudogene
# 54                    O  actin, beta pseudogene 6|actin, gamma 1 pseudo...
# 95                    O  adenylate cyclase type 8|ATP pyrophosphate-lya...
# 125                   O  alpha-1A adrenergic receptor|G protein coupled...
# 131                   O  beta-3 adrenergic receptor|adrenergic, beta-3-...
# 237                   O                               angiopoietin-1|ANG-1
# 238                   O  angiopoietin-2|Tie2-ligand|angiopoietin-2B|ang...
# 239                   O  ankyrin-1|ANK-1|ankyrin 1, erythrocytic|ankyri...
#
#      Modification_date Feature_type
# 3             20210302            -
# 4             20210322            -
# 5             20210302            -
# 54            20210302            -
# 95            20210302            -
# 125           20210302            -
# 131           20210322            -
# 237           20210406            -
# 238           20210406            -
# 239           20210302            -

# %% [markdown]
# Αυτό:
#
# ```python
# hs[hs['chromosome'] == '8']
# ```
#
# Αξίζει να το ξαναδούμε. Καταρχήν μπορεί να "ξενίζει" η διπλή αναφορά στο hs και η διπλή χρήση του ```..[..[```. Αλλά αν προσέξουμε μας δίνει ένα πολύ δυνατό και εκφραστικό εργαλείο να ορίζουμε φίλτρα δεδομένων. Επίσης δεν πρέπει να ξεχνάμε ότι ακριβώς τον ίδιο μηχανισμό χρησιμοποιεί η R και η Matlab. Αφού λοιπόν τα φίλτρα είναι πίνακες από λογικές τιμές, μπορούμε να κάνουμε λογικές πράξεις!
#
# Τα γονίδια που ανήκουν στο χρωμόσωμα 8 και είναι pseudo genes:

# %%
hs[ (hs['chromosome'] == '8') & (hs['type_of_gene'] == 'pseudo') ]
# Out:
#        #tax_id     GeneID        Symbol LocusTag           Synonyms  \
# 5         9606         11          NATP        -         AACP|NATP1
# 54        9606         66        ACTBP6        -    H8-PSI-BETA-AC3
# 568       9606        693        BTF3P1        -            HUMBTFA
# 1289      9606       1587        ADAM3A        -  ADAM3|CYRN1|tMDCI
# 2019      9606       2503       FTH1P11        -             FTHL11
# ...        ...        ...           ...      ...                ...
# 58933     9606  112268397  LOC112268397        -                  -
# 58934     9606  112268399  LOC112268399        -                  -
# 59895     9606  112935968       PTMAP15        -                  -
# 60739     9606  115482726        H2AZP7        -                  -
# 61434     9606  117751737     HIKESHIP3        -                  -
#
#                                        dbXrefs chromosome map_location  \
# 5                                 HGNC:HGNC:15          8         8p22
# 54                               HGNC:HGNC:139          8       8q21.2
# 568                             HGNC:HGNC:1129          8      8q11.23
# 1289     HGNC:HGNC:209|Ensembl:ENSG00000197475          8      8p11.22
# 2019                            HGNC:HGNC:3981          8      8q21.13
# ...                                        ...        ...          ...
# 58933                                        -          8            -
# 58934                                        -          8            -
# 59895                          HGNC:HGNC:53985          8       8q22.3
# 60739  HGNC:HGNC:54440|Ensembl:ENSG00000253156          8       8q23.3
# 61434  HGNC:HGNC:54904|Ensembl:ENSG00000271081          8         8p12
#
#                                         description type_of_gene  \
# 5                    N-acetyltransferase pseudogene       pseudo
# 54                                ACTB pseudogene 6       pseudo
# 568                               BTF3 pseudogene 1       pseudo
# 1289   ADAM metallopeptidase domain 3A (pseudogene)       pseudo
# 2019           ferritin heavy chain 1 pseudogene 11       pseudo
# ...                                             ...          ...
# 58933                40S ribosomal protein S24-like       pseudo
# 58934  putative protein N-methyltransferase FAM86B1       pseudo
# 59895               prothymosin alpha pseudogene 15       pseudo
# 60739                    H2A.Z histone pseudogene 7       pseudo
# 61434                          HIKESHI pseudogene 3       pseudo
#
#       Symbol_from_nomenclature_authority  \
# 5                                   NATP
# 54                                ACTBP6
# 568                               BTF3P1
# 1289                              ADAM3A
# 2019                             FTH1P11
# ...                                  ...
# 58933                                  -
# 58934                                  -
# 59895                            PTMAP15
# 60739                             H2AZP7
# 61434                          HIKESHIP3
#
#               Full_name_from_nomenclature_authority Nomenclature_status  \
# 5                    N-acetyltransferase pseudogene                   O
# 54                                ACTB pseudogene 6                   O
# 568                               BTF3 pseudogene 1                   O
# 1289   ADAM metallopeptidase domain 3A (pseudogene)                   O
# 2019           ferritin heavy chain 1 pseudogene 11                   O
# ...                                             ...                 ...
# 58933                                             -                   -
# 58934                                             -                   -
# 59895               prothymosin alpha pseudogene 15                   O
# 60739                    H2A.Z histone pseudogene 7                   O
# 61434                          HIKESHI pseudogene 3                   O
#
#                                       Other_designations  Modification_date  \
# 5                         arylamide acetylase pseudogene           20210302
# 54     actin, beta pseudogene 6|actin, gamma 1 pseudo...           20210302
# 568    basic transcription factor 3, pseudogene 1|lam...           20210302
# 1289   a disintegrin and metalloproteinase domain 3a ...           20210302
# 2019   ferritin, heavy polypeptide 1 pseudogene 11|fe...           20210302
# ...                                                  ...                ...
# 58933                                                  -           20210302
# 58934                                                  -           20210302
# 59895                                                  -           20210302
# 60739                                                  -           20210302
# 61434                                                  -           20210302
#
#       Feature_type
# 5                -
# 54               -
# 568              -
# 1289             -
# 2019             -
# ...            ...
# 58933            -
# 58934            -
# 59895            -
# 60739            -
# 61434            -
#
# [690 rows x 16 columns]

# %% [markdown]
# ΠΡΟΣΟΧΗ! Οι παρενθέσεις είναι υποχρεωτικές:
#
# ```
# hs[ (hs['chromosome'] == '8') & (hs['type_of_gene'] == 'pseudo') ]
#     ^                       ^   ^                              ^
# ```
#
# Για μια στιγμή, γιατί δεν χρησιμοποιήσαμε τον αγαπημένο μας τελεστή and και χρησημοποιήσαμε αυτό το ```&``` ; Θυμόμαστε ότι το αποτέλεσμα της and είναι **πάντα** (ακόμα και στη pandas) λογικές τιμές (δηλαδή είτε True είτε False). Ναι αλλά εμείς δεν θέλουμε True ή False θέλουμε λίστες από True ή False. Για να κάνουμε αυτή τη διάκριση χρησιμοποιούμε το ```&```.
#
# Οι τελεστές που μπορούμε να χρησιμοποιήσουμε είναι:
# * ```&``` --> and
# * ```|``` --> or
# * ```~``` --> not
#
# Για παράδειγμα: Όλα τα γονίδια που ΔΕΝ ανήκουν στο χρωμόσωμα 8 ή 9 και είναι pseudo genes (τυπώνουμε τα πρώτα 5):

# %%
hs[~((hs['chromosome'] == 8) | (hs['chromosome'] == 9)) & (hs['type_of_gene'] == 'pseudo')][:5]
# Out:
#     #tax_id  GeneID  Symbol LocusTag    Synonyms  \
# 2      9606       3   A2MP1        -        A2MP
# 5      9606      11    NATP        -  AACP|NATP1
# 51     9606      62  ACTBP2        -           -
# 52     9606      63  ACTBP3        -           -
# 53     9606      64  ACTBP4        -           -
#
#                                 dbXrefs chromosome map_location  \
# 2   HGNC:HGNC:8|Ensembl:ENSG00000256069         12     12p13.31
# 5                          HGNC:HGNC:15          8         8p22
# 51                        HGNC:HGNC:135          5       5q14.1
# 52                        HGNC:HGNC:136         18     18q21.32
# 53                        HGNC:HGNC:137          5       5q31.1
#
#                            description type_of_gene  \
# 2   alpha-2-macroglobulin pseudogene 1       pseudo
# 5       N-acetyltransferase pseudogene       pseudo
# 51                   ACTB pseudogene 2       pseudo
# 52                   ACTB pseudogene 3       pseudo
# 53                   ACTB pseudogene 4       pseudo
#
#    Symbol_from_nomenclature_authority Full_name_from_nomenclature_authority  \
# 2                               A2MP1    alpha-2-macroglobulin pseudogene 1
# 5                                NATP        N-acetyltransferase pseudogene
# 51                             ACTBP2                     ACTB pseudogene 2
# 52                             ACTBP3                     ACTB pseudogene 3
# 53                             ACTBP4                     ACTB pseudogene 4
#
#    Nomenclature_status                 Other_designations  Modification_date  \
# 2                    O  pregnancy-zone protein pseudogene           20210302
# 5                    O     arylamide acetylase pseudogene           20210302
# 51                   O           actin, beta pseudogene 2           20210302
# 52                   O           actin, beta pseudogene 3           20210302
# 53                   O           actin, beta pseudogene 4           20210302
#
#    Feature_type
# 2             -
# 5             -
# 51            -
# 52            -
# 53            -

# %% [markdown]
# Υπάρχουν πολλές συναρτήσεις της pandas οι οποίες επιστρέφουν φίλτρα (λίστες από τιμές που είναι True / False). Για παράδειγμα:
#
# Αν ένα πεδίο περιέχει ένα string:

# %%
hs[hs['description'].str.contains('membrane')][:5]
# Out:
#      #tax_id  GeneID  Symbol LocusTag                             Synonyms  \
# 243     9606     290   ANPEP        -        APN|CD13|GP150|LAP1|P150|PEPN
# 411     9606     490  ATP2B1        -                        PMCA1|PMCA1kb
# 412     9606     491  ATP2B2        -                  PMCA2|PMCA2a|PMCA2i
# 413     9606     492  ATP2B3        -  CFAP39|CLA2|OPCA|PMCA3|PMCA3a|SCAX1
# 414     9606     493  ATP2B4        -     ATP2B2|MXRA1|PMCA4|PMCA4b|PMCA4x
#
#                                               dbXrefs chromosome map_location  \
# 243  MIM:151530|HGNC:HGNC:500|Ensembl:ENSG00000166825         15      15q26.1
# 411  MIM:108731|HGNC:HGNC:814|Ensembl:ENSG00000070961         12     12q21.33
# 412  MIM:108733|HGNC:HGNC:815|Ensembl:ENSG00000157087          3       3p25.3
# 413  MIM:300014|HGNC:HGNC:816|Ensembl:ENSG00000067842          X         Xq28
# 414  MIM:108732|HGNC:HGNC:817|Ensembl:ENSG00000058668          1       1q32.1
#
#                                     description    type_of_gene  \
# 243             alanyl aminopeptidase, membrane  protein-coding
# 411  ATPase plasma membrane Ca2+ transporting 1  protein-coding
# 412  ATPase plasma membrane Ca2+ transporting 2  protein-coding
# 413  ATPase plasma membrane Ca2+ transporting 3  protein-coding
# 414  ATPase plasma membrane Ca2+ transporting 4  protein-coding
#
#     Symbol_from_nomenclature_authority  \
# 243                              ANPEP
# 411                             ATP2B1
# 412                             ATP2B2
# 413                             ATP2B3
# 414                             ATP2B4
#
#           Full_name_from_nomenclature_authority Nomenclature_status  \
# 243             alanyl aminopeptidase, membrane                   O
# 411  ATPase plasma membrane Ca2+ transporting 1                   O
# 412  ATPase plasma membrane Ca2+ transporting 2                   O
# 413  ATPase plasma membrane Ca2+ transporting 3                   O
# 414  ATPase plasma membrane Ca2+ transporting 4                   O
#
#                                     Other_designations  Modification_date  \
# 243  aminopeptidase N|AP-M|AP-N|alanyl (membrane) a...           20210316
# 411  plasma membrane calcium-transporting ATPase 1|...           20210327
# 412  plasma membrane calcium-transporting ATPase 2|...           20210302
# 413  plasma membrane calcium-transporting ATPase 3|...           20210302
# 414  plasma membrane calcium-transporting ATPase 4|...           20210302
#
#     Feature_type
# 243            -
# 411            -
# 412            -
# 413            -
# 414            -

# %% [markdown]
# Το ίδιο με πριν αλλά κάνει match αγνοώντας μικρά/κεφαλαία:

# %%
hs[hs['description'].str.contains('membrane', case=False)][:5]
# Out:
#      #tax_id  GeneID  Symbol LocusTag                             Synonyms  \
# 243     9606     290   ANPEP        -        APN|CD13|GP150|LAP1|P150|PEPN
# 411     9606     490  ATP2B1        -                        PMCA1|PMCA1kb
# 412     9606     491  ATP2B2        -                  PMCA2|PMCA2a|PMCA2i
# 413     9606     492  ATP2B3        -  CFAP39|CLA2|OPCA|PMCA3|PMCA3a|SCAX1
# 414     9606     493  ATP2B4        -     ATP2B2|MXRA1|PMCA4|PMCA4b|PMCA4x
#
#                                               dbXrefs chromosome map_location  \
# 243  MIM:151530|HGNC:HGNC:500|Ensembl:ENSG00000166825         15      15q26.1
# 411  MIM:108731|HGNC:HGNC:814|Ensembl:ENSG00000070961         12     12q21.33
# 412  MIM:108733|HGNC:HGNC:815|Ensembl:ENSG00000157087          3       3p25.3
# 413  MIM:300014|HGNC:HGNC:816|Ensembl:ENSG00000067842          X         Xq28
# 414  MIM:108732|HGNC:HGNC:817|Ensembl:ENSG00000058668          1       1q32.1
#
#                                     description    type_of_gene  \
# 243             alanyl aminopeptidase, membrane  protein-coding
# 411  ATPase plasma membrane Ca2+ transporting 1  protein-coding
# 412  ATPase plasma membrane Ca2+ transporting 2  protein-coding
# 413  ATPase plasma membrane Ca2+ transporting 3  protein-coding
# 414  ATPase plasma membrane Ca2+ transporting 4  protein-coding
#
#     Symbol_from_nomenclature_authority  \
# 243                              ANPEP
# 411                             ATP2B1
# 412                             ATP2B2
# 413                             ATP2B3
# 414                             ATP2B4
#
#           Full_name_from_nomenclature_authority Nomenclature_status  \
# 243             alanyl aminopeptidase, membrane                   O
# 411  ATPase plasma membrane Ca2+ transporting 1                   O
# 412  ATPase plasma membrane Ca2+ transporting 2                   O
# 413  ATPase plasma membrane Ca2+ transporting 3                   O
# 414  ATPase plasma membrane Ca2+ transporting 4                   O
#
#                                     Other_designations  Modification_date  \
# 243  aminopeptidase N|AP-M|AP-N|alanyl (membrane) a...           20210316
# 411  plasma membrane calcium-transporting ATPase 1|...           20210327
# 412  plasma membrane calcium-transporting ATPase 2|...           20210302
# 413  plasma membrane calcium-transporting ATPase 3|...           20210302
# 414  plasma membrane calcium-transporting ATPase 4|...           20210302
#
#     Feature_type
# 243            -
# 411            -
# 412            -
# 413            -
# 414            -

# %% [markdown]
# ### Series
#
# Μία στήλη σε pandas ονομάζεται Series. Με τη describe μπορούμε να έχουμε μία καλή εικόνα των τιμών που περιέχει:

# %%
hs['type_of_gene'].describe()
# Out:
# count              62016
# unique                11
# top       protein-coding
# freq               19696
# Name: type_of_gene, dtype: object

# %% [markdown]
# Οι πράξεις που μπορούμε να κάνουμε σε μία στήλη είναι
#
# Να βρούμε όλες τις μοναδικές τιμές που έχει:

# %%
hs['type_of_gene'].unique()
# Out:
# array(['protein-coding', 'pseudo', 'other', 'unknown', 'ncRNA', 'tRNA',
#        'rRNA', 'scRNA', 'snoRNA', 'snRNA', 'biological-region'],
#       dtype=object)

# %% [markdown]
# Να βρούμε το πλήθος από γραμμές που έχουν κάθε μοναδική τιμή:

# %%
hs['type_of_gene'].value_counts()
# Out:
# protein-coding       19696
# ncRNA                17513
# pseudo               16556
# biological-region     4754
# unknown               1383
# other                  840
# tRNA                   595
# snoRNA                 541
# snRNA                   71
# rRNA                    63
# scRNA                    4
# Name: type_of_gene, dtype: int64

# %% [markdown]
# ### Προσθέτοντας στήλες
#
# Μπορούμε να φτιάξουμε ένα νέο Series από ένα άλλο χρησιμοποιώντας την apply. Η apply παίρνει μία συνάρτηση και την εφαρμόζει σε όλες τις γραμμές επιστρέφοντας ένα νέο Series. Μπορείτε να χρησιμοποιείσετε αυτό το Series σαν μία νέα στήλη.
#
# Για παράδειγμα παρατηρούμε ότι η στήλη ```dbXrefs``` περιέχει πολλούς κωδικούς σε άλλες βάσεις δεδομένων. Μπορούμε να βάλουμε κάποιον από αυτούς τους κωδικούς σε μία νέα στήλη:

# %%
import re
def create_ensembl(row):
    m = re.search(r'Ensembl:(ENSG\d+)', row['dbXrefs'])
    if not m:
        return pd.NA
    
    return m.group(1)

hs['ENSEMBL'] = hs.apply(create_ensembl, axis=1)

# %%
hs[:5]
# Out:
#    #tax_id  GeneID Symbol LocusTag                   Synonyms  \
# 0     9606       1   A1BG        -       A1B|ABG|GAB|HYST2477
# 1     9606       2    A2M        -  A2MD|CPAMD5|FWP007|S863-7
# 2     9606       3  A2MP1        -                       A2MP
# 3     9606       9   NAT1        -       AAC1|MNAT|NAT-1|NATI
# 4     9606      10   NAT2        -            AAC2|NAT-2|PNAT
#
#                                              dbXrefs chromosome map_location  \
# 0     MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410         19     19q13.43
# 1     MIM:103950|HGNC:HGNC:7|Ensembl:ENSG00000175899         12     12p13.31
# 2                HGNC:HGNC:8|Ensembl:ENSG00000256069         12     12p13.31
# 3  MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171428          8         8p22
# 4  MIM:612182|HGNC:HGNC:7646|Ensembl:ENSG00000156006          8         8p22
#
#                           description    type_of_gene  \
# 0              alpha-1-B glycoprotein  protein-coding
# 1               alpha-2-macroglobulin  protein-coding
# 2  alpha-2-macroglobulin pseudogene 1          pseudo
# 3               N-acetyltransferase 1  protein-coding
# 4               N-acetyltransferase 2  protein-coding
#
#   Symbol_from_nomenclature_authority Full_name_from_nomenclature_authority  \
# 0                               A1BG                alpha-1-B glycoprotein
# 1                                A2M                 alpha-2-macroglobulin
# 2                              A2MP1    alpha-2-macroglobulin pseudogene 1
# 3                               NAT1                 N-acetyltransferase 1
# 4                               NAT2                 N-acetyltransferase 2
#
#   Nomenclature_status                                 Other_designations  \
# 0                   O  alpha-1B-glycoprotein|HEL-S-163pA|epididymis s...
# 1                   O  alpha-2-macroglobulin|C3 and PZP-like alpha-2-...
# 2                   O                  pregnancy-zone protein pseudogene
# 3                   O  arylamine N-acetyltransferase 1|N-acetyltransf...
# 4                   O  arylamine N-acetyltransferase 2|N-acetyltransf...
#
#    Modification_date Feature_type          ENSEMBL
# 0           20210302            -  ENSG00000121410
# 1           20210404            -  ENSG00000175899
# 2           20210302            -  ENSG00000256069
# 3           20210302            -  ENSG00000171428
# 4           20210322            -  ENSG00000156006

# %% [markdown]
# Παρατηρούμε ότι η τελευταία στήλη περιέχει το ENSEMBL.
#
# Μπορούμε να προσθέσουμε και μία νέα στήλη με τη map:

# %%
hs['is_pseudo'] = hs['type_of_gene'].map(lambda x : x=='pseudo')

# %%
hs[:5]
# Out:
#    #tax_id  GeneID  Symbol LocusTag                   Synonyms  \
# 0     9606       1    A1BG        -       A1B|ABG|GAB|HYST2477
# 1     9606       2     A2M        -  A2MD|CPAMD5|FWP007|S863-7
# 2     9606       3   A2MP1        -                       A2MP
# 3     9606       9  Mitsos        -       AAC1|MNAT|NAT-1|NATI
# 4     9606      10    NAT2        -            AAC2|NAT-2|PNAT
#
#                                              dbXrefs chromosome map_location  \
# 0     MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410         19     19q13.43
# 1     MIM:103950|HGNC:HGNC:7|Ensembl:ENSG00000175899         12     12p13.31
# 2                HGNC:HGNC:8|Ensembl:ENSG00000256069         12     12p13.31
# 3  MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171428          8         8p22
# 4  MIM:612182|HGNC:HGNC:7646|Ensembl:ENSG00000156006          8         8p22
#
#                           description    type_of_gene  \
# 0              alpha-1-B glycoprotein  protein-coding
# 1               alpha-2-macroglobulin  protein-coding
# 2  alpha-2-macroglobulin pseudogene 1          pseudo
# 3               N-acetyltransferase 1  protein-coding
# 4               N-acetyltransferase 2  protein-coding
#
#   Symbol_from_nomenclature_authority Full_name_from_nomenclature_authority  \
# 0                               A1BG                alpha-1-B glycoprotein
# 1                                A2M                 alpha-2-macroglobulin
# 2                              A2MP1    alpha-2-macroglobulin pseudogene 1
# 3                               NAT1                 N-acetyltransferase 1
# 4                               NAT2                 N-acetyltransferase 2
#
#   Nomenclature_status                                 Other_designations  \
# 0                   O  alpha-1B-glycoprotein|HEL-S-163pA|epididymis s...
# 1                   O  alpha-2-macroglobulin|C3 and PZP-like alpha-2-...
# 2                   O                  pregnancy-zone protein pseudogene
# 3                   O  arylamine N-acetyltransferase 1|N-acetyltransf...
# 4                   O  arylamine N-acetyltransferase 2|N-acetyltransf...
#
#    Modification_date Feature_type  is_pseudo
# 0           20210302            -      False
# 1           20210404            -      False
# 2           20210302            -       True
# 3           20210302            -      False
# 4           20210322            -      False

# %% [markdown]
# ### NA = Not Available
#
# Τι είναι ομως αυτό το ```pd.NA```; Είναι η σταθερά της pandas για όταν δεν υπάρχει (Not Available) μία τιμή. Η pandas  έχει μία μεγάλη συλλογή από συναρτήσεις για να διαχειριστείτε αυτή τη τιμη:
#
# Έλεγχος:

# %%
hs['ENSEMBL'].isna().value_counts()
# Out:
# False    35145
# True     26871
# Name: ENSEMBL, dtype: int64

# %% [markdown]
# Διέγραψε τις γραμμές που η στήλη ENSEMBL είναι NA:

# %%
hs.dropna(subset=['ENSEMBL'])[:5]
# Out:
#    #tax_id  GeneID  Symbol LocusTag                   Synonyms  \
# 0     9606       1    A1BG        -       A1B|ABG|GAB|HYST2477
# 1     9606       2     A2M        -  A2MD|CPAMD5|FWP007|S863-7
# 2     9606       3   A2MP1        -                       A2MP
# 3     9606       9  Mitsos        -       AAC1|MNAT|NAT-1|NATI
# 4     9606      10    NAT2        -            AAC2|NAT-2|PNAT
#
#                                              dbXrefs chromosome map_location  \
# 0     MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410         19     19q13.43
# 1     MIM:103950|HGNC:HGNC:7|Ensembl:ENSG00000175899         12     12p13.31
# 2                HGNC:HGNC:8|Ensembl:ENSG00000256069         12     12p13.31
# 3  MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171428          8         8p22
# 4  MIM:612182|HGNC:HGNC:7646|Ensembl:ENSG00000156006          8         8p22
#
#                           description    type_of_gene  \
# 0              alpha-1-B glycoprotein  protein-coding
# 1               alpha-2-macroglobulin  protein-coding
# 2  alpha-2-macroglobulin pseudogene 1          pseudo
# 3               N-acetyltransferase 1  protein-coding
# 4               N-acetyltransferase 2  protein-coding
#
#   Symbol_from_nomenclature_authority Full_name_from_nomenclature_authority  \
# 0                               A1BG                alpha-1-B glycoprotein
# 1                                A2M                 alpha-2-macroglobulin
# 2                              A2MP1    alpha-2-macroglobulin pseudogene 1
# 3                               NAT1                 N-acetyltransferase 1
# 4                               NAT2                 N-acetyltransferase 2
#
#   Nomenclature_status                                 Other_designations  \
# 0                   O  alpha-1B-glycoprotein|HEL-S-163pA|epididymis s...
# 1                   O  alpha-2-macroglobulin|C3 and PZP-like alpha-2-...
# 2                   O                  pregnancy-zone protein pseudogene
# 3                   O  arylamine N-acetyltransferase 1|N-acetyltransf...
# 4                   O  arylamine N-acetyltransferase 2|N-acetyltransf...
#
#    Modification_date Feature_type          ENSEMBL
# 0           20210302            -  ENSG00000121410
# 1           20210404            -  ENSG00000175899
# 2           20210302            -  ENSG00000256069
# 3           20210302            -  ENSG00000171428
# 4           20210322            -  ENSG00000156006

# %% [markdown]
# Αντικατέστησε τις NA με μία τιμή:

# %%
hs['ENSEMBL'].fillna('Does not exist')
# Out:
# 0        ENSG00000121410
# 1        ENSG00000175899
# 2        ENSG00000256069
# 3        ENSG00000171428
# 4        ENSG00000156006
#               ...
# 62011     Does not exist
# 62012     Does not exist
# 62013     Does not exist
# 62014     Does not exist
# 62015     Does not exist
# Name: ENSEMBL, Length: 62016, dtype: object

# %% [markdown]
# ### Αλλάζοντας μία τιμή
#
# Για να αλλάξουμε μία τιμή πρέπει να ξέρουμε τη γραμμή και τη στήλη. Για την ακρίβεια πρέπει να ξέρουμε το index της γραμμής.

# %%
hs.at[3, 'Symbol'] = 'Mitsos'

# %%
hs[:5]
# Out:
#    #tax_id  GeneID  Symbol LocusTag                   Synonyms  \
# 0     9606       1    A1BG        -       A1B|ABG|GAB|HYST2477
# 1     9606       2     A2M        -  A2MD|CPAMD5|FWP007|S863-7
# 2     9606       3   A2MP1        -                       A2MP
# 3     9606       9  Mitsos        -       AAC1|MNAT|NAT-1|NATI
# 4     9606      10    NAT2        -            AAC2|NAT-2|PNAT
#
#                                              dbXrefs chromosome map_location  \
# 0     MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410         19     19q13.43
# 1     MIM:103950|HGNC:HGNC:7|Ensembl:ENSG00000175899         12     12p13.31
# 2                HGNC:HGNC:8|Ensembl:ENSG00000256069         12     12p13.31
# 3  MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171428          8         8p22
# 4  MIM:612182|HGNC:HGNC:7646|Ensembl:ENSG00000156006          8         8p22
#
#                           description    type_of_gene  \
# 0              alpha-1-B glycoprotein  protein-coding
# 1               alpha-2-macroglobulin  protein-coding
# 2  alpha-2-macroglobulin pseudogene 1          pseudo
# 3               N-acetyltransferase 1  protein-coding
# 4               N-acetyltransferase 2  protein-coding
#
#   Symbol_from_nomenclature_authority Full_name_from_nomenclature_authority  \
# 0                               A1BG                alpha-1-B glycoprotein
# 1                                A2M                 alpha-2-macroglobulin
# 2                              A2MP1    alpha-2-macroglobulin pseudogene 1
# 3                               NAT1                 N-acetyltransferase 1
# 4                               NAT2                 N-acetyltransferase 2
#
#   Nomenclature_status                                 Other_designations  \
# 0                   O  alpha-1B-glycoprotein|HEL-S-163pA|epididymis s...
# 1                   O  alpha-2-macroglobulin|C3 and PZP-like alpha-2-...
# 2                   O                  pregnancy-zone protein pseudogene
# 3                   O  arylamine N-acetyltransferase 1|N-acetyltransf...
# 4                   O  arylamine N-acetyltransferase 2|N-acetyltransf...
#
#    Modification_date Feature_type          ENSEMBL
# 0           20210302            -  ENSG00000121410
# 1           20210404            -  ENSG00000175899
# 2           20210302            -  ENSG00000256069
# 3           20210302            -  ENSG00000171428
# 4           20210322            -  ENSG00000156006

# %% [markdown]
# ### Μετονομασία στήλης

# %%
hs = hs.rename(columns={'ENSEMBL': 'ENSEMBL genes'})

# %% [markdown]
# ### Διαγραφή στήλης:

# %%
hs = hs.drop('ENSEMBL genes', axis=1)

# %% [markdown]
# ### Ημερομηνίες
#
# Πρατηρούμε ότι η στήλη: ```hs['Modification_date']``` έχει ημερομηνίες αλλά η pandas τα βλέπει σαν string. Μπορούμε να αλλάξουμε τον τύπο μίας στήλης και να δηλώσουμε ότι περιέχει ημερομηνίες.
#
# Για να το κάνουμε αυτό πρέπει να δηλώσουμε το format της ημερομηνίας: https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %%
hs['New_date'] = pd.to_datetime(hs['Modification_date'], format='%Y%m%d')

# %% [markdown]
# Προσέξτε τη διαφορά

# %%
hs[['New_date', 'Modification_date']][:10]
# Out:
#     New_date  Modification_date
# 0 2021-03-02           20210302
# 1 2021-04-04           20210404
# 2 2021-03-02           20210302
# 3 2021-03-02           20210302
# 4 2021-03-22           20210322
# 5 2021-03-02           20210302
# 6 2021-03-07           20210307
# 7 2021-03-02           20210302
# 8 2021-03-02           20210302
# 9 2021-03-02           20210302

# %% [markdown]
# Τώρα μπορούμε να κάνουμε ταξινόμηση, filtering, κτλ με βάση την ημερομηνία. Ποιο είναι το γονίδιο το οποίο ανανεώθηκε πιο παλιά:

# %%
hs.iloc[hs['New_date'].idxmin()]
# Out:
# #tax_id                                                               9606
# GeneID                                                                7909
# Symbol                                                                HEMC
# LocusTag                                                                 -
# Synonyms                                                               HCI
# dbXrefs                                                         MIM:602089
# chromosome                                                               -
# map_location                                                             -
# description                              hemangioma, capillary, hereditary
# type_of_gene                                                       unknown
# Symbol_from_nomenclature_authority                                       -
# Full_name_from_nomenclature_authority                                    -
# Nomenclature_status                                                      -
# Other_designations                                                       -
# Modification_date                                                 20170402
# Feature_type                                                             -
# New_date                                               2017-04-02 00:00:00
# Name: 6234, dtype: object

# %% [markdown]
# ### Ταξινόμηση
# Χρησημοποιούμε τη sort_values:

# %%
hs.sort_values('description')[:5]
# Out:
#        #tax_id     GeneID        Symbol LocusTag  \
# 57645     9606  110599572  LOC110599572        -
# 2120      9606       2632          GBE1        -
# 8277      9606      10554        AGPAT1        -
# 8278      9606      10555        AGPAT2        -
# 13332     9606      56894        AGPAT3        -
#
#                                    Synonyms  \
# 57645                                     -
# 2120                          APBD|GBE|GSD4
# 8277        1-AGPAT1|G15|LPAAT-alpha|LPAATA
# 8278   1-AGPAT2|BSCL|BSCL1|LPAAB|LPAAT-beta
# 13332         1-AGPAT 3|LPAAT-GAMMA1|LPAAT3
#
#                                                  dbXrefs chromosome  \
# 57645                                                  -         10
# 2120   MIM:607839|HGNC:HGNC:4180|Ensembl:ENSG00000114480          3
# 8277    MIM:603099|HGNC:HGNC:324|Ensembl:ENSG00000204310          6
# 8278    MIM:603100|HGNC:HGNC:325|Ensembl:ENSG00000169692          9
# 13332   MIM:614794|HGNC:HGNC:326|Ensembl:ENSG00000160216         21
#
#       map_location                                     description  \
# 57645            -                        -8 kb enhancer of CYP2C8
# 2120        3p12.2             1,4-alpha-glucan branching enzyme 1
# 8277       6p21.32  1-acylglycerol-3-phosphate O-acyltransferase 1
# 8278        9q34.3  1-acylglycerol-3-phosphate O-acyltransferase 2
# 13332      21q22.3  1-acylglycerol-3-phosphate O-acyltransferase 3
#
#             type_of_gene Symbol_from_nomenclature_authority  \
# 57645  biological-region                                  -
# 2120      protein-coding                               GBE1
# 8277      protein-coding                             AGPAT1
# 8278      protein-coding                             AGPAT2
# 13332     protein-coding                             AGPAT3
#
#                 Full_name_from_nomenclature_authority Nomenclature_status  \
# 57645                                               -                   -
# 2120              1,4-alpha-glucan branching enzyme 1                   O
# 8277   1-acylglycerol-3-phosphate O-acyltransferase 1                   O
# 8278   1-acylglycerol-3-phosphate O-acyltransferase 2                   O
# 13332  1-acylglycerol-3-phosphate O-acyltransferase 3                   O
#
#                                       Other_designations  Modification_date  \
# 57645                                                  -           20210302
# 2120   1,4-alpha-glucan-branching enzyme|amylo-(1,4 t...           20210302
# 8277   1-acyl-sn-glycerol-3-phosphate acyltransferase...           20210302
# 8278   1-acyl-sn-glycerol-3-phosphate acyltransferase...           20210302
# 13332  1-acyl-sn-glycerol-3-phosphate acyltransferase...           20210302
#
#               Feature_type   New_date
# 57645  regulatory:enhancer 2021-03-02
# 2120                     - 2021-03-02
# 8277                     - 2021-03-02
# 8278                     - 2021-03-02
# 13332                    - 2021-03-02

# %% [markdown]
# ### Από python --> pandas

# %% [markdown]
# Αν έχετε μία δομή σε python μπορείτε να τη μετασχηματίσετε ώστε να μπορεί να μπει σαν είσοδο στη DataFrame και να επιστρέψει ένα DataFrame.
#
# Η DataFrame υποστηρίζει δύο διαφορετικές δομές:
#
# **Δομή 1η:** Λίστα από dictionaries. Κάθε κλειδί στο dictionary είναι το όνομα μίας στήλης:

# %%
l = [
    {'col_1': 1, 'col_2': 1, 'col_3': 'test_1'},
    {'col_1': 2, 'col_2': 4, 'col_3': 'test_2'},
    {'col_1': 3, 'col_2': 5, 'col_3': 'test_5'},
    {'col_1': 1, 'col_2': 1, 'col_3': 'test_2'},
    {'col_1': 1, 'col_2': 2, 'col_3': 'test_4'},
]

df = pd.DataFrame(l)
df
# Out:
#    col_1  col_2   col_3
# 0      1      1  test_1
# 1      2      4  test_2
# 2      3      5  test_5
# 3      1      1  test_2
# 4      1      2  test_4

# %% [markdown]
# **Δομή 2η**: Dictionaries με λίστες:

# %%
l = {
    'col_1': [1,2,3,1,1],
    'col_2': [1,4,5,1,2],
    'col_3': ['test_1', 'test_2', 'test_5', 'test_2', 'test_4'],
}
df = pd.DataFrame(l)
df
# Out:
#    col_1  col_2   col_3
# 0      1      1  test_1
# 1      2      4  test_2
# 2      3      5  test_5
# 3      1      1  test_2
# 4      1      2  test_4

# %% [markdown]
# ### Από pandas --> python
#
# Με τη μέθοδο ```to_dict``` μπορείτε να μετατρέψετε σε dictionary ή λίστα:

# %%
df.to_dict('records') # Λίστα από dictionaries
# Out:
# [{'col_1': 1, 'col_2': 1, 'col_3': 'test_1'},
#  {'col_1': 2, 'col_2': 4, 'col_3': 'test_2'},
#  {'col_1': 3, 'col_2': 5, 'col_3': 'test_5'},
#  {'col_1': 1, 'col_2': 1, 'col_3': 'test_2'},
#  {'col_1': 1, 'col_2': 2, 'col_3': 'test_4'}]

# %%
df.to_dict('index') # Dictionaies από dictionaries. Τα κλειδιά είναι τα indexes
# Out:
# {0: {'col_1': 1, 'col_2': 1, 'col_3': 'test_1'},
#  1: {'col_1': 2, 'col_2': 4, 'col_3': 'test_2'},
#  2: {'col_1': 3, 'col_2': 5, 'col_3': 'test_5'},
#  3: {'col_1': 1, 'col_2': 1, 'col_3': 'test_2'},
#  4: {'col_1': 1, 'col_2': 2, 'col_3': 'test_4'}}

# %%
df.to_dict('dict') # Dictionary από dictionaries. Τα κλειδιά είναι οι στήλες
# Out:
# {'col_1': {0: 1, 1: 2, 2: 3, 3: 1, 4: 1},
#  'col_2': {0: 1, 1: 4, 2: 5, 3: 1, 4: 2},
#  'col_3': {0: 'test_1', 1: 'test_2', 2: 'test_5', 3: 'test_2', 4: 'test_4'}}

# %%
df.to_dict('list') # Dictionary από λίστες. Τα κλειδιά είναι οι στήλες
# Out:
# {'col_1': [1, 2, 3, 1, 1],
#  'col_2': [1, 4, 5, 1, 2],
#  'col_3': ['test_1', 'test_2', 'test_5', 'test_2', 'test_4']}

# %%
pd.DataFrame({0: {'col_1': 1, 'col_2': 1, 'col_3': 'test_1'},
 1: {'col_1': 2, 'col_2': 4, 'col_3': 'test_2'},
 2: {'col_1': 3, 'col_2': 5, 'col_3': 'test_5'},
 3: {'col_1': 1, 'col_2': 1, 'col_3': 'test_2'},
 4: {'col_1': 1, 'col_2': 2, 'col_3': 'test_4'}})
# Out:
#             0       1       2       3       4
# col_1       1       2       3       1       1
# col_2       1       4       5       1       2
# col_3  test_1  test_2  test_5  test_2  test_4

# %% [markdown]
# ### [Σώζοντας ένα pandas](https://wwf.panda.org/discover/knowledge_hub/endangered_species/giant_panda/panda/why_we_save_the_giant_panda/?)  DataFrame

# %% [markdown]
# Τα pandas είναι μία "εξωστρεφής" βιβλιοθήκη. Αυτό σημαίνει ότι μπορεί να σώζει και να φορτώνει από/σε πολλά φορμάτ. Το πιο κοινό είναι το csv:

# %%
df.to_csv('test.csv')

# %%
# !cat test.csv # Για windows: !type test.csv
# Out:
# ,col_1,col_2,col_3
# 0,1,1,test_1
# 1,2,4,test_2
# 2,3,5,test_5
# 3,1,1,test_2
# 4,1,2,test_4

# %%
df.to_csv('test.csv', index=None) # Σώζουμε χωρίς το index

# %%
# !cat test.csv # Για windows: !type test.csv
# Out:
# col_1,col_2,col_3
# 1,1,test_1
# 2,4,test_2
# 3,5,test_5
# 1,1,test_2
# 1,2,test_4

# %% [markdown]
# Μπορούμε να σώσουμε ένα αρχείο σε φορμάτ excel:

# %%
df.to_excel('test.xlsx')

# %% [markdown]
# Και να διαβάσουμε από excel:

# %%
df2 = pd.read_excel('test.xlsx')

# %%
df2
# Out:
#    Unnamed: 0  col_1  col_2   col_3
# 0           0      1      1  test_1
# 1           1      2      4  test_2
# 2           2      3      5  test_5
# 3           3      1      1  test_2
# 4           4      1      2  test_4

# %% [markdown]
# Διαβάστε εδώ: https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html για τα διαφορετικά φορμάτ που μπορούμε να διαβάσουμε και να γράψουμε.

# %% [markdown]
# ### Iteration

# %% [markdown]
# Αν και σπάνια το χρειαζόμαστε ([..και προσπαθούμε να αντίσταθούμε στον πειρασμό να το χρησιμοποιήσουμε](https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas)) μπορούμε να κάνουμε iterate (επανάληψη) σε κάθε γραμμή του DataFrame. Αν και υπάρχουν [πολλοί τρόποι](https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas) για να το κάνουμε αυτό, εδω δείχνουμε το itertuples:

# %%
for x in df2.itertuples():
    print ('Index: ', x.Index, 'col_2', x.col_2)
# Out:
# Index:  0 col_2 1
# Index:  1 col_2 4
# Index:  2 col_2 5
# Index:  3 col_2 1
# Index:  4 col_2 2

# %% [markdown]
# ### Grouping
#
# [Το grouping](https://en.wikipedia.org/wiki/Grouped_data) είναι μία από τις πιο βασικές λειτουργίες των βιβλιοθηκών που χειρίζονται 2-διάστατα δεδομένα. Στην ουσία με το grouping χωρίζουμε τις γραμμές σε groups. Από κάθε group παίρνουμε κάποιες στήλες και σε όλες τις τιμές του group της κάθε στήλης εφαρμόζουμε μία συνάρτηση. Με αυτόν τον τρόπο μπορούμε να κάνουμε πολύ χρήσιμες ερωτήσεις όπως: "για κάθε χρωμόσωμα ποιο είναι το μεγαλύτερο γονίδιο;", "για κάθε νομό ποια είναι η μεγαλύτερη πόλη", "ποιος είναι ο μέσος όρος των γονιδίων που έχουν συσχετιστεί με τον καρκίνο για κάθε χρωμόσωμα;" κτλ..
#
# Η pandas έχει μία βασική δομή για το grouping:
#
# ```text
#
# df.groupby( [ ... ] )[ [...] ].aggregate( ... )
#                |         |                 |
#                |         |                 > Συνάρτηση που θα εφαρμόσουμε σε κάθε group-αρισμένη στήλη
#                |         > Στήλες που θα group-αριστούν
#                > Στήλες που περιέχουν τις τιμές με βάση τις οποίες θα γίνει το  grouping.
#                > Κάθε διαφορετική τιμή τους θα είναι και ένα group
#
# ```
#
# Ας δούμε μερικά παραδείγματα. Φτιάχνουμε ένα random dataframe με 3 στήλες 20 γραμμές και τιμές από 1-4:

# %%
import random

d = {
    'col_1': [random.randint(1,4) for x in range(20)],
    'col_2': [random.randint(1,4) for x in range(20)],
    'col_3': [random.randint(1,4) for x in range(20)],
}
df = pd.DataFrame(d)
df
# Out:
#     col_1  col_2  col_3
# 0       4      4      3
# 1       1      4      3
# 2       4      4      1
# 3       2      2      1
# 4       1      1      3
# 5       1      4      2
# 6       1      1      2
# 7       2      3      3
# 8       4      3      2
# 9       4      4      2
# 10      4      4      1
# 11      2      3      3
# 12      2      4      2
# 13      1      2      4
# 14      4      3      2
# 15      2      4      3
# 16      3      4      3
# 17      1      2      4
# 18      1      3      3
# 19      1      2      1

# %% [markdown]
# Για κάθε διαφορετική τιμή της στήλης col_1, ποια είναι η μικρότερη τιμή της col_2;

# %%
df.groupby(['col_1'])[['col_2']].aggregate('min')
# Out:
#        col_2
# col_1
# 1          1
# 2          2
# 3          4
# 4          3

# %% [markdown]
# Για κάθε διαφορετική τιμή της στήλης ```col_1```, ποια είναι η μικρότερη και μεγαλύτερη τιμή της ```col_2```;

# %%
df.groupby(['col_1'])[['col_2']].aggregate(['min', 'max'])
# Out:
#       col_2
#         min max
# col_1
# 1         1   4
# 2         2   4
# 3         4   4
# 4         3   4

# %% [markdown]
# Για κάθε διαφορετική τιμή της στήλης ```col_1```, ποια είναι η μικρότερη τιμή της στήλης ```col_2``` και μεγαλύτερη τιμή της στήλης ```col_3```;

# %%
df.groupby(['col_1'])[['col_2', 'col_3']].aggregate({'col_2': 'min', 'col_3': 'max'})
# Out:
#        col_2  col_3
# col_1
# 1          1      4
# 2          2      3
# 3          4      3
# 4          3      3

# %% [markdown]
# Για κάθε διαφορετική τιμή της στήλης ```col_1```, ποια είναι η μικρότερη και μεγαλύτερη τιμή της στήλης ```col_2``` και μικρότερη και μεγαλύτερη τιμή της στήλης ```col_3```;

# %%
df.groupby(['col_1'])[['col_2', 'col_3']].aggregate( ['min', 'max'] )
# Out:
#       col_2     col_3
#         min max   min max
# col_1
# 1         1   4     1   4
# 2         2   4     1   3
# 3         4   4     3   3
# 4         3   4     1   3

# %% [markdown]
# Ένα group μπορεί να έχει παραπάνω από μία στήλες. Σε αυτή τη περίπτωση κάθε group περιέχει όλες τις διαφορετικές τιμές που προκύπτουν από τους συνδυασμούς των διαφορετικών τιμών των 2 (ή παραπάνω) στηλών.
#
# Για όλες τις διαφορετικές τιμές της στήλης ```col_1``` και ```col_2``` ποια είναι η μικρότερη τιμή της στήλης ```col_3```;

# %%
df.groupby(['col_1', 'col_2'])[['col_3']].aggregate('min')
# Out:
#              col_3
# col_1 col_2
# 1     1          2
#       2          1
#       3          3
#       4          2
# 2     2          1
#       3          3
#       4          2
# 3     4          3
# 4     3          2
#       4          1

# %% [markdown]
# Σαν aggregate functions μπορείτε να βάλετε [[πηγή](https://cmdlinetips.com/2019/10/pandas-groupby-13-functions-to-aggregate/)]:
#
#
# * ```mean()```: Compute mean of groups
# * ```sum()```: Compute sum of group values
# * ```size()```: Compute group sizes
# * ```count()```: Compute count of group
# * ```std()```: Standard deviation of groups
# * ```var()```: Compute variance of groups
# * ```sem()```: Standard error of the mean of groups
# * ```describe()```: Generates descriptive statistics
# * ```first()```: Compute first of group values
# * ```last()```: Compute last of group values
# * ```nth()``` : Take nth value, or a subset if n is a list
# * ```min()```: Compute min of group values
# * ```max()```: Compute max of group values

# %% [markdown]
# Ας δούμε μερικά παραδείγματα από τα "δικά μας" δεδομένα.
#
# Πόσα γονίδια έχει κάθε χρωμόσωμα;

# %%
hs.groupby('chromosome')[['GeneID']].aggregate('count')
# Out:
#             GeneID
# chromosome
# -              146
# 1             5826
# 10            2463
# 10|19|3          1
# 11            3302
# 12            2826
# 13            1557
# 14            2290
# 15            2098
# 16            2255
# 17            2812
# 18            1122
# 19            2825
# 2             4471
# 20            1521
# 21             885
# 22            1409
# 3             3470
# 4             2743
# 5             2943
# 6             3478
# 7             3200
# 8             2470
# 9             2581
# MT             110
# Un              66
# X             2492
# X|Y             66
# Y              588

# %% [markdown]
# Για κάθε ένα από τα χρωμοσώματα X και Y, πόσα διαφορετικά γονίδια υπάρχουν;

# %%
hs[hs['chromosome'].isin(['X', 'Y'])].groupby(['chromosome', 'type_of_gene'])[['GeneID']].aggregate('count')
# Out:
#                               GeneID
# chromosome type_of_gene
# X          biological-region     157
#            ncRNA                 442
#            other                  10
#            protein-coding        830
#            pseudo                906
#            snoRNA                 16
#            tRNA                    5
#            unknown               126
# Y          biological-region      11
#            ncRNA                 107
#            other                  29
#            protein-coding         46
#            pseudo                389
#            unknown                 6

# %% [markdown]
# Ας αλλάξουμε τη σειρά των στηλών στο grouping:

# %%
hs2 = hs[hs['chromosome'].isin(['X', 'Y'])].groupby(['type_of_gene', 'chromosome'])[['GeneID']].aggregate('count')
hs2
# Out:
#                               GeneID
# type_of_gene      chromosome
# biological-region X              157
#                   Y               11
# ncRNA             X              442
#                   Y              107
# other             X               10
#                   Y               29
# protein-coding    X              830
#                   Y               46
# pseudo            X              906
#                   Y              389
# snoRNA            X               16
# tRNA              X                5
# unknown           X              126
#                   Y                6

# %% [markdown]
# Κάτι αρκετά εξεζητημένο είναι ότι μπορούμε να εφαρμόσουμε μία συνάρτηση σε κάθε group με την apply. Για παράδειγμα Για κάθε type_of_gene ποιο είναι το ποσοσότ που ανήκει στο χρωμόσωμα X και ποιο το αντίστοιχο για το χρωμόσωμα Y;

# %%
hs2.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))
# Out:
#                                   GeneID
# type_of_gene      chromosome
# biological-region X            93.452381
#                   Y             6.547619
# ncRNA             X            80.510018
#                   Y            19.489982
# other             X            25.641026
#                   Y            74.358974
# protein-coding    X            94.748858
#                   Y             5.251142
# pseudo            X            69.961390
#                   Y            30.038610
# snoRNA            X           100.000000
# tRNA              X           100.000000
# unknown           X            95.454545
#                   Y             4.545455

# %% [markdown]
# Το level σημαίνει σε ποιο "group" (από τα δύο που έχουμε εφαρμόσουμε) να γίνει το apply. Η αλήθεια είναι οτι αφού το X έχει πολύ περισσότερα γονίδια από το Y ο παραπάνω πίνακας δεν μας λέει και πάρα πολλά. Ας κάνουμε apply με τη function στο δεύτερο level:

# %%
hs3 = hs2.groupby(level=1).apply(lambda x: 100 * x / float(x.sum()))
hs3
# Out:
#                                  GeneID
# type_of_gene      chromosome
# biological-region X            6.300161
#                   Y            1.870748
# ncRNA             X           17.736758
#                   Y           18.197279
# other             X            0.401284
#                   Y            4.931973
# protein-coding    X           33.306581
#                   Y            7.823129
# pseudo            X           36.356340
#                   Y           66.156463
# snoRNA            X            0.642055
# tRNA              X            0.200642
# unknown           X            5.056180
#                   Y            1.020408

# %% [markdown]
# Ενδιαφέρον: Στο χρωμόσωμα X το 33.3% των γονίδιων που περιέχει είναι protein-coding. Το αντίστοιχο ποσοστό για το Y είναι 7.8%. Ενώ για το Y το 66.2% των γονιδίων είναι pseudo και για το Χ είναι 36.3%. Μάλλον δεν κάνει και πολλά πράγματα το Y..

# %% [markdown]
# Μπορούμε να του πούμε: Το πρώτο group κάντο στήλες:

# %%
hs3.unstack(0)
# Out:
#                         GeneID                                                 \
# type_of_gene biological-region      ncRNA     other protein-coding     pseudo
# chromosome
# X                     6.300161  17.736758  0.401284      33.306581  36.356340
# Y                     1.870748  18.197279  4.931973       7.823129  66.156463
#
#
# type_of_gene    snoRNA      tRNA   unknown
# chromosome
# X             0.642055  0.200642  5.056180
# Y                  NaN       NaN  1.020408

# %% [markdown]
# Ή το 2ο group κάντο στήλες:

# %%
hs3.unstack(1)
# Out:
#                       GeneID
# chromosome                 X          Y
# type_of_gene
# biological-region   6.300161   1.870748
# ncRNA              17.736758  18.197279
# other               0.401284   4.931973
# protein-coding     33.306581   7.823129
# pseudo             36.356340  66.156463
# snoRNA              0.642055        NaN
# tRNA                0.200642        NaN
# unknown             5.056180   1.020408

# %% [markdown]
# Το unstacking είναι σημαντικό γιατί μας επιτρέπει να κάνουμε τα groups μπάρες (δες και συνέχεια)

# %%
hs3.unstack(1).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='type_of_gene'>

# %% [markdown]
# Εδώ βλέπουμε πως κάναμε μία "επεξεργασία" των δεδομένων χωρίς να κάνουμε ούτε μία for, if, κτλ.. Αυτός είναι ο "[δηλωτικός τρόπος προγραμματισμού](https://en.wikipedia.org/wiki/Declarative_programming)". Συνιθίζεται όταν γράφουμε πολλές εντολές που κάνουν διαδοχικές επεξεργασίες να τις γράφουμε με αυτό το στυλ (method chaining):

# %%
(hs[hs['chromosome'].isin(['X', 'Y'])]
 .groupby(['type_of_gene', 'chromosome'])[['GeneID']]
 .aggregate('count')
 .groupby(level=1)
 .apply(lambda x: 100 * x / float(x.sum()))
 .unstack(1)
 .plot(kind='bar')
)
# Out:
# <AxesSubplot:xlabel='type_of_gene'>

# %% [markdown]
# ### Plotting
#
# Η pandas υποστηρίζει ένα μεγάλο πλήθος από plots. Σε μελλοντικό μάθημα θα ασχοληθούμε περισσότερο με το πως κάνουμε plots χωρίς της pandas.
#
# Barplots: πλήθος απο γονίδια ανά χρωμόσωμα:

# %%
hs['chromosome'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Το ίδιο σε piechart. **ΠΡΟΣΟΧΗ!!** Αποφεύγουμε να χρησιμοποιούμε piechart σε επιστημονικές δημοσιεύσεις! Google: ```why are pie charts bad```

# %%
hs['chromosome'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='chromosome'>

# %% [markdown]
# # Ένα παράδειγμα με GWAS

# %% [markdown]
# Ας χρησιμοποιήσουμε έναν κατάλογο από [GWA studies](https://en.wikipedia.org/wiki/Genome-wide_association_study). O κατάλογος βρίσκεται σε αυτό το link: https://www.ebi.ac.uk/gwas/api/search/downloads/full για να το φορτώσετε τρέξτε (κάνει πολύ ώρα!):

# %%
gwas = pd.read_csv('https://www.ebi.ac.uk/gwas/api/search/downloads/full', sep='\t')
# Out:
# /Users/admin/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (9,11,12,23,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# Οι στήλες:

# %%
gwas.columns
# Out:
# Index(['DATE ADDED TO CATALOG', 'PUBMEDID', 'FIRST AUTHOR', 'DATE', 'JOURNAL',
#        'LINK', 'STUDY', 'DISEASE/TRAIT', 'INITIAL SAMPLE SIZE',
#        'REPLICATION SAMPLE SIZE', 'REGION', 'CHR_ID', 'CHR_POS',
#        'REPORTED GENE(S)', 'MAPPED_GENE', 'UPSTREAM_GENE_ID',
#        'DOWNSTREAM_GENE_ID', 'SNP_GENE_IDS', 'UPSTREAM_GENE_DISTANCE',
#        'DOWNSTREAM_GENE_DISTANCE', 'STRONGEST SNP-RISK ALLELE', 'SNPS',
#        'MERGED', 'SNP_ID_CURRENT', 'CONTEXT', 'INTERGENIC',
#        'RISK ALLELE FREQUENCY', 'P-VALUE', 'PVALUE_MLOG', 'P-VALUE (TEXT)',
#        'OR or BETA', '95% CI (TEXT)', 'PLATFORM [SNPS PASSING QC]', 'CNV'],
#       dtype='object')

# %% [markdown]
# Ποια είναι τα 10 γονίδια στα οποία έχουν γίνει τα περισσότερα GWAS;

# %%
gwas["MAPPED_GENE"].value_counts()[:10].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Μετατροπή του DATE από string σε datetime

# %%
gwas['DATE'] = pd.to_datetime(gwas["DATE"]) # Μετατροπή του DATE από string σε datetime

# %% [markdown]
# Ας δούμε μερικά χαρακτηριστικά της στήλης P-VALUE ;

# %%
gwas['PVALUE_MLOG'].describe()
# Out:
# count    251401.000000
# mean         17.671208
# std          66.731631
# min           5.000000
# 25%           7.000000
# 50%           9.301030
# 75%          14.698970
# max       22135.221849
# Name: PVALUE_MLOG, dtype: float64

# %% [markdown]
# Ας τη κάνουμε plot με βάση τον χρόνο:

# %%
gwas.plot(x='DATE', y='PVALUE_MLOG')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
gwas[gwas['PVALUE_MLOG']<1000].plot(x='DATE', y='PVALUE_MLOG')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# Πόσα gwas δημοσιεύονται κάθε χρόνο;

# %%
gwas.groupby(gwas['DATE'].dt.year)['DATE'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# Ένας άλλος τρόπος να τα πλοτάρουμε:

# %%
gwas.groupby(gwas['DATE'].dt.year)['DATE'].count().plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# Ας πάρουμε όλα τα GWAS που έχουν γίνει σε ασθένειες ή φαινότυπους που έχουν μέσα τη λέξη "Breast", και τα SNPs που έχουν βρεθεί έχουν συσχετιστεί με p-value<10<sup>-10</sup>, και ας τα κατατάξουμε σε χρωμοσώματα:

# %%
(
    gwas[ (gwas["DISEASE/TRAIT"].str.contains('Breast')) & (gwas["PVALUE_MLOG"]>10)]
    .groupby("CHR_ID")['CHR_ID']
    .aggregate('count').plot(kind='bar')
)
# Out:
# <AxesSubplot:xlabel='CHR_ID'>

# %% [markdown]
# Λογικό ότι το χρωμόσωμα 5 που έχει το BRCA2 gene είναι #1

# %% [markdown]
# Ποιος είναι ο ερευνητής που έχει τις περισσότερες δημοσιεύσεις στο Nature Genetics;

# %%
(
    gwas[gwas['JOURNAL'] == 'Nat Genet']
    .groupby('FIRST AUTHOR')
    .aggregate('count')['PUBMEDID']
    .idxmax()
)
# Out:
# 'Lee JJ'

# %% [markdown]
# Ποιο region περιέχει τις περισσότερες μελέτες σχετικά με καρκίνο;

# %%
(
    gwas[gwas['DISEASE/TRAIT'].str.contains('cancer', case=False, na=False)]
    .groupby('REGION')
    .aggregate('count')['PUBMEDID']
    .idxmax()
)
# Out:
# '8q24.21'

# %% [markdown]
# Ποιος είναι ο μέσος όρος και το median του allele_frequency για όλα τα variants που ανακαλύπτοντε κάθε χρόνο;

# %%
gwas['RISK ALLELE FREQUENCY']=pd.to_numeric(gwas['RISK ALLELE FREQUENCY'], errors='coerce')

gwas_2 = ( 
 gwas
 .groupby(gwas_2['DATE'].dt.year)['RISK ALLELE FREQUENCY']
 .aggregate(['mean', 'median'])
)
gwas_2
# Out:
#             mean    median
# DATE
# 2005.0       NaN       NaN
# 2006.0  0.370000  0.370000
# 2007.0  0.415373  0.400000
# 2008.0  0.389350  0.350000
# 2009.0  0.362769  0.320000
# 2010.0  0.358266  0.330000
# 2011.0  0.384316  0.340000
# 2012.0  0.340888  0.300000
# 2013.0  0.414986  0.380000
# 2014.0  0.420903  0.390000
# 2015.0  0.498522  0.477000
# 2016.0  0.367788  0.338245
# 2017.0  0.382940  0.335076
# 2018.0  0.473471  0.474000
# 2019.0  0.403819  0.381000
# 2020.0  0.438670  0.416900
# 2021.0  0.385103  0.359920

# %% [markdown]
# Ας κάνουμε ένα scatter plot με τον x να είναι το YEAR και το y να είναι τα mean και median

# %%
gwas_2.plot(style='.')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# Και ένα scatter plot με το χ να είναι το mean και το y το median:

# %%
gwas_2.plot.scatter(x='mean', y='median')
# Out:
# <AxesSubplot:xlabel='mean', ylabel='median'>

# %% [markdown]
# ### Περισσότερα
#
# * [Cheatsheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# * [Introduction to Pandas](https://realpython.com/pandas-dataframe/) . [plotting with pandas](https://realpython.com/pandas-plot-python/)
# * [100 pandas puzzles](https://github.com/ajcr/100-pandas-puzzles)
